# %%
import pandas as pd

# %%
df = pd.read_csv('https://tinyurl.com/alugueis-sp-df')

# %%
df.head(2)
# Out:
#    Price  Condo  Size  Rooms  Toilets  Suites  Parking  Elevator  Furnished  \
# 0    930    220    47      2        2       1        1         0          0
# 1   1000    148    45      2        2       1        1         0          0
#
#    Swimming Pool  New               District Negotiation Type Property Type  \
# 0              0    0  Artur Alvim/São Paulo             rent     apartment
# 1              0    0  Artur Alvim/São Paulo             rent     apartment
#
#     Latitude  Longitude
# 0 -23.543138 -46.479486
# 1 -23.550239 -46.480718

# %%
c1 = df['Price'] > 2000
c2 = df['Elevator'] == 1
c3 = df['Size'] > 45
c4 = df['Rooms'] >= 3

df[c1& c2 & c3 & c4]
# Out:
#          Price  Condo  Size  Rooms  Toilets  Suites  Parking  Elevator  \
# 25        2300    857   113      3        2       1        2         1
# 32        3000    811   107      3        3       1        2         1
# 33        6000    800   150      3        4       3        2         1
# 35        2500    857   113      3        2       1        2         1
# 36        3800   1450   155      3        4       3        3         1
# ...        ...    ...   ...    ...      ...     ...      ...       ...
# 13572  1499999   1000   147      3        4       3        3         1
# 13590  1300000   1500   130      3        2       1        2         1
# 13592  1050000   1400   100      3        2       1        2         1
# 13595  2800000   2000   180      3        3       2        3         1
# 13605   540000    650    89      3        2       1        2         1
#
#        Furnished  Swimming Pool  New              District Negotiation Type  \
# 25             0              0    0       BELÉM/SÃO PAULO             rent
# 32             0              1    0       BELÉM/SÃO PAULO             rent
# 33             1              0    0       BELÉM/SÃO PAULO             rent
# 35             0              0    0       BELÉM/SÃO PAULO             rent
# 36             1              0    0       BELÉM/SÃO PAULO             rent
# ...          ...            ...  ...                   ...              ...
# 13572          1              1    0    IPIRANGA/SÃO PAULO             sale
# 13590          0              0    0  ITAIM BIBI/SÃO PAULO             sale
# 13592          0              0    0  ITAIM BIBI/SÃO PAULO             sale
# 13595          1              0    0  ITAIM BIBI/SÃO PAULO             sale
# 13605          0              1    0   JABAQUARA/SÃO PAULO             sale
#
#       Property Type   Latitude  Longitude
# 25        apartment -23.538134 -46.594059
# 32        apartment -23.538767 -46.594706
# 33        apartment -23.550987 -46.590908
# 35        apartment -23.538134 -46.594059
# 36        apartment -23.540085 -46.593312
# ...             ...        ...        ...
# 13572     apartment -23.505391 -46.622783
# 13590     apartment -23.579758 -46.674122
# 13592     apartment -23.586720 -46.676470
# 13595     apartment -23.578793 -46.675166
# 13605     apartment -23.550520 -46.633309
#
# [1670 rows x 16 columns]

# %%
# 5 maiores apartamentos
df.sort_values('Size').tail(5)
# Out:
#        Price  Condo  Size  Rooms  Toilets  Suites  Parking  Elevator  \
# 3800   25000   7500   627      4        5       4        6         0
# 10669  30000   8800   640      4        5       4        5         0
# 3408   50000   5500   670      5        6       5        7         0
# 10698   8700   5040   852      7        6       5        6         1
# 3865   19900   7800   880      5        4       5        6         1
#
#        Furnished  Swimming Pool  New              District Negotiation Type  \
# 3800           0              1    0       Moema/São Paulo             rent
# 10669          1              1    0       Moema/São Paulo             rent
# 3408           0              1    0  Campo Belo/São Paulo             rent
# 10698          0              1    0     Morumbi/São Paulo             rent
# 3865           0              0    0     Morumbi/São Paulo             rent
#
#       Property Type   Latitude  Longitude
# 3800      apartment -23.605854 -46.655442
# 10669     apartment -23.599839 -46.664336
# 3408      apartment -23.625617 -46.674614
# 10698     apartment -26.922512 -49.060707
# 3865      apartment -23.623140 -46.719525

# %%
# 10 mais caros - desempatet tamanho
df.sort_values(['Price', 'Size']).tail(10)
# Out:
#          Price  Condo  Size  Rooms  Toilets  Suites  Parking  Elevator  \
# 8949   7521000   2500   377      6        7       6        4         0
# 7623   7559420      0   377      3        4       3        4         1
# 8935   7559420      0   377      3        4       3        4         0
# 6286   7765616      0   279      4        6       4        4         1
# 7152   8000000      0   269      4        5       4        4         1
# 5006   8000000      0   278      4        5       3        5         1
# 5008   8039200      0   278      4        7       4        4         1
# 7249   8500000   7200   420      4        6       4        4         1
# 6287   9979947      0   343      4        6       4        5         1
# 6282  10000000      0   343      4        7       4        5         0
#
#       Furnished  Swimming Pool  New                     District  \
# 8949          0              1    0  Alto de Pinheiros/São Paulo
# 7623          0              1    0  Alto de Pinheiros/São Paulo
# 8935          0              1    0  Alto de Pinheiros/São Paulo
# 6286          0              1    0           Iguatemi/São Paulo
# 7152          0              1    0         Itaim Bibi/São Paulo
# 5006          0              1    0       Vila Olimpia/São Paulo
# 5008          1              1    0       Vila Olimpia/São Paulo
# 7249          0              1    0    Jardim Paulista/São Paulo
# 6287          0              1    0           Iguatemi/São Paulo
# 6282          0              0    0           Iguatemi/São Paulo
#
#      Negotiation Type Property Type   Latitude  Longitude
# 8949             sale     apartment -23.549506 -46.717449
# 7623             sale     apartment -23.549505 -46.717448
# 8935             sale     apartment -23.549506 -46.717449
# 6286             sale     apartment -23.585487 -46.681676
# 7152             sale     apartment -23.588294 -46.680764
# 5006             sale     apartment -23.596469 -46.680587
# 5008             sale     apartment -23.596469 -46.680587
# 7249             sale     apartment -23.564044 -46.660862
# 6287             sale     apartment -23.585487 -46.681676
# 6282             sale     apartment -23.585487 -46.681676

# %%
# upperCasing district column
df['District'] = df['District'].str.upper()

# %%
import matplotlib.pyplot as plt
# configurações adicionais para os gráficos a serem gerados
from matplotlib import rc 
plt.rcParams["figure.figsize"] = [10,5]
# definimos o estilo dos gráficos
# veja mais estilos em https://matplotlib.org/3.1.1/gallery/#style-sheets
plt.style.use("fivethirtyeight") 
# %config InlineBackend.figure_format = 'retina' #formato das imagens
rc('font',**{'family':'sans-serif','sans-serif':['DejaVu Sans'],'size':10}) #fonte utilizada
rc('mathtext',**{'default':'regular'})
df.dropna(inplace=True)

# %%
df[['Price','Rooms']].boxplot(by='Rooms');

# %%
df.plot.scatter(x='Size', y='Price')

# %%
df[['Price','Size']].plot.hist()
